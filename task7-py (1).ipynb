# %%
requirements = """
transformers
datasets
torch
scikit-learn
wandb
huggingface_hub
"""

with open("requirements.txt", "w") as f:
    f.write(requirements)

print("requirements.txt created successfully")
# Out:
# requirements.txt created successfully

# %%
readme = """
# BERT Text Classification Project

## Project Description
This project performs text classification using DistilBERT transformer model from Hugging Face. The model was trained and evaluated using PyTorch, Transformers, and Weights & Biases for experiment tracking.

## Setup Instructions

Install dependencies:

pip install -r requirements.txt

Run the scripts:

python task5.py
python task6.py

## Results

| Metric | Score |
|--------|--------|
| Accuracy | 1.0 |
| F1 Score | 1.0 |
| Eval Loss | 0.63413 |

## Hugging Face Model
https://huggingface.co/sanjay-mlops/sanjay-bert-model

## W&B Dashboard
https://wandb.ai/

"""

with open("README.md", "w") as f:
    f.write(readme)

print("README.md created successfully")
# Out:
# README.md created successfully

# %%
import os
print(os.listdir())
# Out:
# ['requirements.txt', '.virtual_documents', 'README.md']
